# %%
import os
import os.path
import pickle
from itertools import product

import bdpy
import h5py
import numpy
import pandas as pd
import slir
from bdpy import get_refdata, makedir_ifnot
from bdpy.ml import add_bias
from bdpy.preproc import select_top
from bdpy.stats import corrcoef
from matplotlib import pyplot as plt


# TODO: read article and do parameter optimization + model design

def main():
    subjects = {'s1': os.path.abspath('data/Subject1.h5'),
                's2': os.path.abspath('data/Subject2.h5'),
                's3': os.path.abspath('data/Subject3.h5'),
                's4': os.path.abspath('data/Subject4.h5'),
                's5': os.path.abspath('data/Subject5.h5'),
                'imageFeature': os.path.abspath('data/ImageFeatures.h5')}

    regine_of_interest = {'VC': 'ROI_VC = 1',
                          'LVC': 'ROI_LVC = 1',
                          'HVC': 'ROI_HVC = 1',
                          'V1': 'ROI_V1 = 1',
                          'V2': 'ROI_V2 = 1',
                          'V3': 'ROI_V3 = 1',
                          'V4': 'ROI_V4 = 1',
                          'LOC': 'ROI_LOC = 1',
                          'FFA': 'ROI_FFA = 1',
                          'PPA': 'ROI_PPA = 1'}

    voxel = {'VC': 1000,
             'LVC': 1000,
             'HVC': 1000,
             'V1': 500,
             'V2': 500,
             'V3': 500,
             'V4': 500,
             'LOC': 500,
             'FFA': 500,
             'PPA': 500}

    layers = ['cnn1', 'cnn2', 'cnn3', 'cnn4', 'cnn5', 'cnn6', 'cnn7', 'cnn8',
              'hmax1', 'hmax2', 'hmax3',
              'gist', 'sift']

    print('=======================================')
    print('Data loading...')

    dataset = {}
    image_feature = {}

    file = None

    for person in subjects:

        file = h5py.File(subjects[person], 'r')

        if person != 'imageFeature':
            # Subject 1 ~ 5
            print(person, '---------------------')
            print('data: ', file.keys())

            dataset[person] = bdpy.BData(subjects[person])

        else:
            image_feature = bdpy.BData(subjects[person])

    file.close()

    print('--------------------- data ')
    print('s1: %s\n'
          's2: %s\n'
          's3: %s\n'
          's4: %s\n'
          's5: %s' % (dataset['s1'].dataset.shape,
                      dataset['s2'].dataset.shape,
                      dataset['s3'].dataset.shape,
                      dataset['s4'].dataset.shape,
                      dataset['s5'].dataset.shape))

    # dataset & metadata collected
    data_prepare(dataset, regine_of_interest, image_feature, layers, voxel)


def data_prepare(subject, rois, img_feature, layers, voxel):
    print('Data prepare:')
    print('-----------------')

    # For plot ========================================================
    repeat = 3
    time = 0

    norm_none = []
    norm_z = []
    norm_min_max = []
    norm_t = []
    norm_binary = []
    average_loss = []

    # For plot ========================================================

    for sbj, roi, layer in product(subject, rois, layers):
        data = subject[sbj]
        x = data.select(rois[roi])
        print('-----------------------------------')
        print('roi: %s, subject: %s, layer: %s' % (roi, sbj, layer))

        data_type = data.select('DataType')
        labels = data.select('stimulus_id')

        y = img_feature.select(layer)
        y_label = img_feature.select('ImageID')

        y_sort = bdpy.get_refdata(y, y_label, labels)  # labels -> y_label -> y

        # Flatten(): transfer the shape from vertical to horizontal
        i_train = (data_type == 1).flatten()
        i_test_seen = (data_type == 2).flatten()
        i_test_img = (data_type == 3).flatten()

        # test data, add seen and imagined data together
        i_test = i_test_img + i_test_seen

        # get training & test data in x
        x_train = x[i_train, :]
        x_test = x[i_test, :]

        # get training & test data in y
        y_train = y_sort[i_train, :]
        y_test = y_sort[i_test, :]

        for i in range(repeat):

            if i == 0:
                print('No normalizing =============================')
                pred_y, true_y = algorithm_predict_feature(x_train=x_train, y_train=y_train,
                                                           x_test=x_test, y_test=y_test,
                                                           num_voxel=voxel[roi], information=[sbj, roi, layer], norm=i)
                norm_none = pred_y
                average_loss.append(avg_loss(pred_y[0, :]))

            elif i == 1:
                print('Z-score normalization using ================')
                pred_y, true_y = algorithm_predict_feature(x_train=x_train, y_train=y_train,
                                                           x_test=x_test, y_test=y_test,
                                                           num_voxel=voxel[roi], information=[sbj, roi, layer], norm=i)
                norm_z = pred_y
                average_loss.append(avg_loss(pred_y[0, :]))

            elif i == 2:
                print('Min-Max normalization using ================')
                pred_y, true_y = algorithm_predict_feature(x_train=x_train, y_train=y_train,
                                                           x_test=x_test, y_test=y_test,
                                                           num_voxel=voxel[roi], information=[sbj, roi, layer], norm=i)
                norm_min_max = pred_y
                average_loss.append(avg_loss(pred_y[0, :]))

            elif i == 3:
                print('T-static normalization using ===============')
                pred_y, true_y = algorithm_predict_feature(x_train=x_train, y_train=y_train,
                                                           x_test=x_test, y_test=y_test,
                                                           num_voxel=voxel[roi], information=[sbj, roi, layer], norm=i)
                norm_t = pred_y
                average_loss.append(avg_loss(pred_y[0, :]))

            elif i == 4:
                print('Binary normalization using =================')
                pred_y, true_y = algorithm_predict_feature(x_train=x_train, y_train=y_train,
                                                           x_test=x_test, y_test=y_test,
                                                           num_voxel=voxel[roi], information=[sbj, roi, layer], norm=i)
                norm_binary = pred_y
                average_loss.append(avg_loss(pred_y[0, :]))

        break

        # Separate results for perception and imagery tests
        i_pt = i_test_seen[i_test]  # Index for perception test within test
        i_im = i_test_img[i_test]  # Index for imagery test within test

        pred_y_pt = pred_y[i_pt, :]
        pred_y_im = pred_y[i_im, :]

        true_y_pt = true_y[i_pt, :]
        true_y_im = true_y[i_im, :]

        # Get averaged predicted feature
        test_label_pt = labels[i_test_seen, :].flatten()
        test_label_im = labels[i_test_img, :].flatten()

        pred_y_pt_av, true_y_pt_av, test_label_set_pt \
            = get_averaged_feature(pred_y_pt, true_y_pt, test_label_pt)
        pred_y_im_av, true_y_im_av, test_label_set_im \
            = get_averaged_feature(pred_y_im, true_y_im, test_label_im)

        print('Predict average seen feature: ', pred_y_pt_av)
        print('True average seen feature: ', true_y_pt_av)
        print('Predict average imaginary feature: ', pred_y_im_av)
        print('True average imaginary feature: ', true_y_im_av)

        # Get category averaged features
        cat_labels_pt = np.vstack([int(n) for n in test_label_pt])  # Category labels (perception test)
        cat_labels_im = np.vstack([int(n) for n in test_label_im])  # Category labels (imagery test)
        cat_labels_set_pt = np.unique(cat_labels_pt)  # Category label set (perception test)
        cat_labels_set_im = np.unique(cat_labels_im)  # Category label set (imagery test)

        y_cat_labels = img_feature.select('CatID')  # Category labels in image features
        ind_cat_av = (img_feature.select('FeatureType') == 3).flatten()

        y_cat_av_pt = get_refdata(y[ind_cat_av, :], y_cat_labels[ind_cat_av, :], cat_labels_set_pt)
        y_cat_av_im = get_refdata(y[ind_cat_av, :], y_cat_labels[ind_cat_av, :], cat_labels_set_im)

        # Prepare result dataframe
        results = pd.DataFrame({'subject': [sbj, sbj],
                                'roi': [roi, roi],
                                'feature': [layer, layer],
                                'test_type': ['perception', 'imagery'],
                                'true_feature': [true_y_pt, true_y_im],
                                'predicted_feature': [pred_y_pt, pred_y_im],
                                'test_label': [test_label_pt, test_label_im],
                                'test_label_set': [test_label_set_pt, test_label_set_im],
                                'true_feature_averaged': [true_y_pt_av, true_y_im_av],
                                'predicted_feature_averaged': [pred_y_pt_av, pred_y_im_av],
                                'category_label_set': [cat_labels_set_pt, cat_labels_set_im],
                                'category_feature_averaged': [y_cat_av_pt, y_cat_av_im]})

        # Save results
        analysis_id = sbj + '-' + roi + '-' + layer
        results_file = os.path.join('bxz056/plots', analysis_id + '.pkl')

        makedir_ifnot(os.path.dirname(results_file))
        with open(results_file, 'wb') as f:
            pickle.dump(results, f)

        print('Saved %s' % results_file)

    condition = 4

    plt.figure(figsize=(10, 12))
    plt.suptitle('Prediction with different normalization')

    plt.subplot(condition, 1, 1)
    plt.title('No normalization')
    plt.bar(range(1000), norm_none[0, :])

    plt.subplot(condition, 1, 2)
    plt.title('Z-score')
    plt.bar(range(1000), norm_z[0, :])

    plt.subplot(condition, 1, 3)
    plt.title('Min-Max')
    plt.bar(range(1000), norm_min_max[0, :])

    # plt.subplot(6, 1, 4)
    # plt.title('T-static')
    # plt.bar(range(1000), norm_t[0, :])
    #
    # plt.subplot(6, 1, 5)
    # plt.title('Binary')
    # plt.bar(range(1000), norm_binary[0, :])

    average_loss = numpy.array(average_loss)
    print('average loss: ', average_loss.shape)

    plt.subplot(condition, 1, condition)
    plt.title('Difference')
    plt.bar(range(4), average_loss)

    plt.tight_layout(rect=[0, 0, 1, 0.99])


def avg_loss(array):
    loss_avg = 0

    for j in array:
        loss_avg += j

    return loss_avg / 1000


def algorithm_predict_feature(x_train, y_train, x_test, y_test, num_voxel, 
                              information: list, norm: (0, 1, 2, 3)):
    # Plot setting for not python scientific model
    # plt.figure(figsize=(10, 8))

    # Training iteration
    n_iter = 200

    # Normalize brian data (x)
    if norm == 0:
        x_train = x_train
        x_test = x_test

    elif norm == 1:
        norm_mean_x = numpy.mean(x_train, axis=0)
        norm_scale_x = numpy.std(x_train, axis=0, ddof=1)

        x_train = (x_train - norm_mean_x) / norm_scale_x
        x_test = (x_test - norm_mean_x) / norm_scale_x

    elif norm == 2:
        x_min = numpy.min(x_train)
        x_max = numpy.max(x_train)

        x_train = (x_train - x_min) / (x_max - x_min)
        x_test = (x_test - x_min) / (x_max - x_min)

    # save predict value
    model = slir.SparseLinearRegression(n_iter=n_iter, prune_mode=1)
    y_pred_all = []

    for i in range(1000):

        print('Subject: %s, Roi: %s, Layer: %s, Voxel: %d' %
              (information[0], information[1], information[2], i))

        # SIFT descriptor normalization
        y_train_unit = y_train[:, i]
        y_test_unit = y_test[:, i]

        # Normalization of image feature
        if norm == 0:
            y_train_unit = y_train_unit
            y_test_unit = y_test_unit

        elif norm == 1:
            norm_mean_y = numpy.mean(y_train_unit, axis=0)
            std_y = numpy.std(y_train_unit, axis=0, ddof=1)
            norm_scale_y = 1 if std_y == 0 else std_y

            y_train_unit = (y_train_unit - norm_mean_y) / norm_scale_y

        elif norm == 2:
            y_min = numpy.min(x_train)
            y_max = numpy.max(x_train)

            x_train = (x_train - y_min) / (y_max - y_min)
            x_test = (x_test - y_min) / (y_max - y_min)

        # correlate with y and x
        correlation = corrcoef(y_train_unit, x_train, var='col')

        x_train, voxel_index = select_top(x_train, numpy.abs(correlation),
                                          num_voxel, axis=1,
                                          verbose=False)

        x_test = x_test[:, voxel_index]

        # Add bias terms
        x_train = add_bias(x_train, axis=1)
        x_test = add_bias(x_test, axis=1)

        # ===================================================================================
        # define the neural network architecture (convolutional net) ------------------------

        # Training and test
        try:
            model.fit(x_train, y_train_unit)  # Training
            y_pred = model.predict(x_test)  # Test

        except Exception as e:
            print('x_test_unit: ', x_test.shape)
            print('y_test_unit: ', y_test_unit.shape)
            print('x_train_unit: ', x_train.shape)
            print('y_train_unit: ', y_train_unit.shape)

            print(e)
            y_pred = numpy.zeros(y_test_unit.shape)
        # -----------------------------------------------------------------------------------
        # ===================================================================================

        # y_pred = y_pred * norm_scale_y + norm_mean_y  # denormalize
        y_pred_all.append(y_pred)

    y_predicted = numpy.vstack(y_pred_all).T

    return y_predicted, y_test


def get_averaged_feature(pred_y, true_y, labels):
    """Return category-averaged features"""

    labels_set = numpy.unique(labels)

    pred_y_av = numpy.array([numpy.mean(pred_y[labels == c, :], axis=0) for c in labels_set])
    true_y_av = numpy.array([numpy.mean(true_y[labels == c, :], axis=0) for c in labels_set])

    return pred_y_av, true_y_av, labels_set


# =========================================================================

# run Project
# ========================
main()
# Out:
# =======================================
# Data loading...
# s1 ---------------------
# data:  <KeysViewHDF5 ['dataset', 'header', 'metadata', 'vmap']>
# s2 ---------------------
# data:  <KeysViewHDF5 ['callStack', 'callStackCode', 'createDate', 'createDateRaw', 'createScript', 'dataSet', 'metaData']>
# s3 ---------------------
# data:  <KeysViewHDF5 ['dataset', 'header', 'metadata', 'vmap']>
# s4 ---------------------
# data:  <KeysViewHDF5 ['dataset', 'header', 'metadata', 'vmap']>
# s5 ---------------------
# data:  <KeysViewHDF5 ['dataset', 'header', 'metadata', 'vmap']>
# --------------------- data
# s1: (3450, 4471)
# s2: (3450, 4409)
# s3: (3450, 4648)
# s4: (3450, 4138)
# s5: (3450, 4375)
# Data prepare:
# -----------------
# -----------------------------------
# roi: VC, subject: s1, layer: cnn1
# No normalizing =============================
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 0
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 1
# E:\Anaconda\lib\site-packages\numpy\lib\function_base.py:2642: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# E:\Anaconda\lib\site-packages\numpy\lib\function_base.py:2643: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 2
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 3
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 4
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 5
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 6
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 7
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 8
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 9
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 10
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 11
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 12
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 13
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 14
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 15
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 16
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 17
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 18
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 19
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 20
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 21
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 22
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 23
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 24
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 25
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 26
# Subject: s1, Roi: VC, Layer: cnn1, Voxel:
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 856
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 857
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 858
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 859
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 860
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 861
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 862
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 863
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 864
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 865
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 866
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 867
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 868
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 869
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 870
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 871
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 872
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 873
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 874
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 875
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 876
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 877
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 878
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 879
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 880
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 881
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 882
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 883
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 884
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 885
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 886
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 887
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 888
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 889
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 890
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 891
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 892
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 893
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 894
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 895
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 896
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 897
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 898
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 899
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 900
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 901
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 902
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 903
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 904
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 905
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 906
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 907
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 908
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 909
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 910
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 911
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 912
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 913
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 914
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 915
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 916
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 917
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 918
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 919
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 920
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 921
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 922
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 923
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 924
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 925
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 926
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 927
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 928
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 929
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 930
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 931
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 932
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 933
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 934
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 935
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 936
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 937
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 938
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 939
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 940
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 941
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 942
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 943
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 944
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 945
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 946
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 947
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 948
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 949
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 950
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 951
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 952
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 953
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 954
# x_test_unit:  (2250, 1001)
# y_test_unit:  (2250,)
# x_train_unit:  (1200, 1001)
# y_train_unit:  (1200,)
# All dimensions are pruned.
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 955
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 956
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 957
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 958
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 959
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 960
# x_test_unit:  (2250, 1001)
# y_test_unit:  (2250,)
# x_train_unit:  (1200, 1001)
# y_train_unit:  (1200,)
# All dimensions are pruned.
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 961
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 962
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 963
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 964
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 965
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 966
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 967
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 968
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 969
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 970
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 971
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 972
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 973
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 974
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 975
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 976
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 977
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 978
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 979
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 980
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 981
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 982
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 983
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 984
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 985
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 986
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 987
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 988
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 989
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 990
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 991
# x_test_unit:  (2250, 1001)
# y_test_unit:  (2250,)
# x_train_unit:  (1200, 1001)
# y_train_unit:  (1200,)
# All dimensions are pruned.
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 992
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 993
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 994
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 995
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 996
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 997
# x_test_unit:  (2250, 1001)
# y_test_unit:  (2250,)
# x_train_unit:  (1200, 1001)
# y_train_unit:  (1200,)
# All dimensions are pruned.
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 998
# Subject: s1, Roi: VC, Layer: cnn1, Voxel: 999
# average loss:  (3,)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-6325aa16e3c7> in <module>
#     400 # run Project
#     401 # ========================
# --> 402 main()
#
# <ipython-input-1-6325aa16e3c7> in main()
#      88
#      89     # dataset & metadata collected
# ---> 90     data_prepare(dataset, regine_of_interest, image_feature, layers, voxel)
#      91
#      92
#
# <ipython-input-1-6325aa16e3c7> in data_prepare(subject, rois, img_feature, layers, voxel)
#     272     plt.subplot(condition, 1, condition)
#     273     plt.title('Difference')
# --> 274     plt.bar(range(4), average_loss)
#     275
#     276     plt.tight_layout(rect=[0, 0, 1, 0.99])
#
# E:\Anaconda\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2485         x, height, width=0.8, bottom=None, *, align='center',
#    2486         data=None, **kwargs):
# -> 2487     return gca().bar(
#    2488         x, height, width=width, bottom=bottom, align=align,
#    2489         **({"data": data} if data is not None else {}), **kwargs)
#
# E:\Anaconda\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# E:\Anaconda\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2428                 yerr = self._convert_dx(yerr, y0, y, self.convert_yunits)
#    2429
# -> 2430         x, height, width, y, linewidth = np.broadcast_arrays(
#    2431             # Make args iterable too.
#    2432             np.atleast_1d(x), height, width, y, linewidth)
#
# <__array_function__ internals> in broadcast_arrays(*args, **kwargs)
#
# E:\Anaconda\lib\site-packages\numpy\lib\stride_tricks.py in broadcast_arrays(subok, *args)
#     536     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     537
# --> 538     shape = _broadcast_shape(*args)
#     539
#     540     if all(array.shape == shape for array in args):
#
# E:\Anaconda\lib\site-packages\numpy\lib\stride_tricks.py in _broadcast_shape(*args)
#     418     # use the old-iterator because np.nditer does not handle size 0 arrays
#     419     # consistently
# --> 420     b = np.broadcast(*args[:32])
#     421     # unfortunately, it cannot handle 32 or more arguments directly
#     422     for pos in range(32, len(args), 31):
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape

# %%
# Out:
# <function __main__.avg_loss(array)>
